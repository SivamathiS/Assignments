# %%
print("Hope AI")
# Out:
# Hope AI

# %%
str_name = input("Enter your institute name? :")
# Out:
# Enter your institute name? : Hope AI

# %%
Name = input("Enter your Name: ")
Age = input("Enter your Age: ")
school = input("Enter your school name: ")
dgr = input("Enter your degree: ")
# Out:
# Enter your Name:  Raj
# Enter your Age:  21
# Enter your school name:  Guru School
# Enter your degree:  BE CSE

# %%
a= 43
b= 34
print ("a= ", a)
print ("b= ", b)
print ("add= ", a+b)
# Out:
# a=  43
# b=  34
# add=  77

# %%
a= 43
b= 34
print ("a= ", a)
print ("b= ", b)
print ("sub= ", a-b)
# Out:
# a=  43
# b=  34
# sub=  9

# %%
a= 63
b= 97
print ("a= ", a)
print ("b= ", b)
print ("mul= ", a*b)
# Out:
# a=  63
# b=  97
# mul=  6111

# %%
a= 76
b= 31
div = a/b
print ("a= ", a)
print ("b= ", b)
print ("Float Div = ", div)
# Out:
# a=  76
# b=  31
# Float Div =  2.4516129032258065

# %%
a= 76
b= 31
div = a//b
print ("a= ", a)
print ("b= ", b)
print ("Floor Div = ", div)
# Out:
# a=  76
# b=  31
# Floor Div =  2

# %%
a= 76
b= 31
div = a%b
print ("a= ", a)
print ("b= ", b)
print ("Modulo = ", div)
# Out:
# a=  76
# b=  31
# Modulo =  14

# %%
a= 4
b= 4
pwr = a**b
print ("a= ", a)
print ("b= ", b)
print ("Power = ", pwr)
# Out:
# a=  4
# b=  4
# Power =  256
