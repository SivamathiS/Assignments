# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
dtset = pd.read_csv("50_Startups.csv")
dtset.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
dtset = pd.get_dummies(dtset,drop_first=True)
independant = dtset.drop('Profit', axis=1)
dept = dtset[['Profit']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(independant, dept, test_size = 1/3, random_state=0)
x_train.shape
# Out:
# (33, 5)

# %%
y_train.shape
# Out:
# (33, 1)

# %%
from sklearn.svm import SVR
regressor = SVR(kernel="linear", C=0.1)
regressor = regressor.fit(x_train, y_train)
# Out:
# C:\Users\ssiva\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
weight = regressor.coef_
bias = regressor.intercept_
print("weight is", weight)
print("bias is:", bias)
regressor.support_
regressor.n_support_
regressor.support_vectors_
# Out:
# weight is [[ 0.76394145  0.04655445  0.04389052  0.28454473 -0.10738669]]
# bias is: [41221.60356811]
# array([[1.0002300e+03, 1.2415304e+05, 1.9039300e+03, 0.0000000e+00,
#         1.0000000e+00],
#        [5.4205000e+02, 5.1743150e+04, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00],
#        [6.5605480e+04, 1.5303206e+05, 1.0713838e+05, 0.0000000e+00,
#         1.0000000e+00],
#        [1.1452361e+05, 1.2261684e+05, 2.6177623e+05, 0.0000000e+00,
#         1.0000000e+00],
#        [6.1994480e+04, 1.1564128e+05, 9.1131240e+04, 1.0000000e+00,
#         0.0000000e+00],
#        [6.3408860e+04, 1.2921961e+05, 4.6085250e+04, 0.0000000e+00,
#         0.0000000e+00],
#        [7.8013110e+04, 1.2159755e+05, 2.6434606e+05, 0.0000000e+00,
#         0.0000000e+00],
#        [2.3640930e+04, 9.6189630e+04, 1.4800111e+05, 0.0000000e+00,
#         0.0000000e+00],
#        [7.6253860e+04, 1.1386730e+05, 2.9866447e+05, 0.0000000e+00,
#         0.0000000e+00],
# ...

# %%
y_predict = regressor.predict(x_test)
from sklearn.metrics import r2_score
rscore=r2_score(y_test, y_predict)
rscore
# Out:
# 0.9198778359741281

# %%
rd_input=float(input("R&D:"))
admin_input=float(input("Admin"))
mark_input=float(input("Marketing "))
fol_input=int(input("State_flo 0 or 1:"))
new_input=int(input("State_new 0 or 1:"))

result=regressor.predict([[rd_input,admin_input,mark_input,fol_input,new_input]])
result
# Out:
# R&D: 2000
# Admin 400
# Marketing  4000
# State_flo 0 or 1: 0
# State_new 0 or 1: 0
# C:\Users\ssiva\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# array([42943.67033542])
