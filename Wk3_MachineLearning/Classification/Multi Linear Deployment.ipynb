# %%
import pickle

# %%
save_model=pickle.load(open("mulline_final.sav",'rb'))

# %%
rd_input=float(input("R&D:"))
admin_input=float(input("Admin"))
mark_input=float(input("Marketing "))
fol_input=int(input("State_flo 0 or 1:"))
new_input=int(input("State_new 0 or 1:"))

result=save_model.predict([[rd_input,admin_input,mark_input,fol_input,new_input]])
result
# Out:
# R&D: 25000
# Admin 1000
# Marketing  20000
# State_flo 0 or 1: 0
# State_new 0 or 1: 1
# C:\Users\ssiva\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[60013.87810577]])

# %%
result
# Out:
# array([[92299.22034455]])
